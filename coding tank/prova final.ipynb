# %%
def remove_forn(cod_forn, dic):

    dic.pop(cod_forn)

dic_empresa = {}
cod_forn = 1

while True:

    print('\n********* Cadastro de Fornecedores *********')
    print('Digite sua opção:')
    print('1 - Cadastro')
    print('2 - Remoção de Dado')
    print('0 - Encerrar')
    opcao = int(input('Opção: '))

    if opcao < 1:
        print('\nFim do Programa.')
        break

    elif opcao > 2:
        opcao = int(input('\nOpção inválida! Digite novamente: '))

    elif opcao == 2:
        dado_remover = input('\nDigite o codigo do fornecedor que deseja remover: ')

        while dado_remover not in dic_empresa:
            dado_remover = input('\nFornecedor inexistente! Digite novamente: ')

        remove_forn(dado_remover, dic_empresa)
        print(f'\nDado do fornecedor {nome} removido!')

    else:
        forn = {}

        print('\nSobre os dados, informe: ')
        cod = input('O código: ')
        nome = input('O nome: ')
        tel = input('O telefone: ')
        email = input('O email: ')

        forn['Código'] = cod
        forn['Nome'] = nome
        forn['Telefone'] = tel
        forn['Email'] = email

        dic_empresa[cod] = forn 

        cod_forn += 1


print('Dados Armazenados: ')
print(dic_empresa)
# Out:
# ********* Cadastro de Fornecedores *********
# Digite sua opção:
# 1 - Cadastro
# 2 - Remoção de Dado
# 0 - Encerrar
# Opção: 1
#
# Sobre os dados, informe:
# O código: BEDED
# O nome: AlexFrutas
# O telefone: 31958255455
# O email: alexfrutas@gmail.com
#
# ********* Cadastro de Fornecedores *********
# Digite sua opção:
# 1 - Cadastro
# 2 - Remoção de Dado
# 0 - Encerrar
# Opção: 1
#
# Sobre os dados, informe:
# O código: BDEDDD
# O nome: Atacadao Moveis
# O telefone: 32698544788
# O email: atacadao@gmail.com
#
# ********* Cadastro de Fornecedores *********
# Digite sua opção:
# 1 - Cadastro
# 2 - Remoção de Dado
# 0 - Encerrar
# Opção: 2
#
# Digite o codigo do fornecedor que deseja remover: BDEDDD
#
# Dado do fornecedor Atacadao Moveis removido!
#
# ********* Cadastro de Fornecedores *********
# Digite sua opção:
# 1 - Cadastro
# 2 - Remoção de Dado
# 0 - Encerrar
# Opção: 2
#
# Digite o codigo do fornecedor que deseja remover: BEDED
#
# ...
