# %%
class ContaCorrente:
    
    def __init__(self, nome, cpf):
        self.nome = nome
        self.cpf = cpf
        self.saldo = 0
        
       
    def consultar_saldo(self):
        print('Seu saldo atual é de R${:,.2f}'.format(self.saldo))
        
    def depositar(self, valor):
        self.saldo += valor
            
    def sacar_dinheiro(self, valor):
        self.saldo -= valor
    
    
#programa

conta_Lira = ContaCorrente("Lira", "111.222.333-45")
conta_Lira.consultar_saldo()

#depositando
conta_Lira.depositar(10000)
conta_Lira.consultar_saldo()

#sacando
conta_Lira.sacar_dinheiro(1000)
conta_Lira.consultar_saldo()
# Out:
# Seu saldo atual é de R$0.00
# Seu saldo atual é de R$10,000.00
# Seu saldo atual é de R$9,000.00

# %%
class ContaCorrente:
    
    def __init__(self, nome, cpf):
        self.nome = nome
        self.cpf = cpf
        self.saldo = 0
        self.limite = None
       
    def consultar_saldo(self):
        print('Seu saldo atual é de R${:,.2f}'.format(self.saldo))
        
    def depositar(self, valor):
        self.saldo += valor
            
    def limite_conta(self):
        self.limite = -1000
        return self.limite
    
    def sacar_dinheiro(self, valor):
        if self.saldo - valor < self.limite_conta():
            print('Você não tem saldo suficiente para sacar esse valor')
            self.consultar_saldo()
        else:
            self.saldo -= valor
    
    
#programa

conta_Lira = ContaCorrente("Lira", "111.222.333-45")
conta_Lira.consultar_saldo()

#depositando
conta_Lira.depositar(10000)
conta_Lira.consultar_saldo()

#sacando
conta_Lira.sacar_dinheiro(100000)
print('Saldo Final')
conta_Lira.consultar_saldo()
# Out:
# Seu saldo atual é de R$0.00
# Seu saldo atual é de R$10,000.00
# Você não tem saldo suficiente para sacar esse valor
# Seu saldo atual é de R$10,000.00
# Saldo Final
# Seu saldo atual é de R$10,000.00

# %%
class ContaCorrente:
    
    def __init__(self, nome, cpf):
        self.nome = nome
        self.cpf = cpf
        self.saldo = 0
        self.limite = None
       
    def consultar_saldo(self):
        print('Seu saldo atual é de R${:,.2f}'.format(self.saldo))
        
    def depositar(self, valor):
        self.saldo += valor
            
    def limite_conta(self):
        self.limite = -1000
        return self.limite
    
    def sacar_dinheiro(self, valor):
        if self.saldo - valor < self.limite_conta():
            print('Você não tem saldo suficiente para sacar esse valor')
            self.consultar_saldo()
        else:
            self.saldo -= valor
    
    
#programa

conta_Lira = ContaCorrente("Lira", "111.222.333-45")
conta_Lira.consultar_saldo()

#depositando
conta_Lira.depositar(10000)
conta_Lira.consultar_saldo()

#sacando
conta_Lira.sacar_dinheiro(11500)
print('Saldo Final')
conta_Lira.consultar_saldo()
# Out:
# Seu saldo atual é de R$0.00
# Seu saldo atual é de R$10,000.00
# Você não tem saldo suficiente para sacar esse valor
# Seu saldo atual é de R$10,000.00
# Saldo Final
# Seu saldo atual é de R$10,000.00

# %%
class ContaCorrente:
    
    def __init__(self, nome, cpf):
        self.nome = nome
        self.cpf = cpf
        self.saldo = 0
        self.limite = None
       
    def consultar_saldo(self):
        print('Seu saldo atual é de R${:,.2f}'.format(self.saldo))
        
    def depositar(self, valor):
        self.saldo += valor
            
    def limite_conta(self):
        self.limite = -1000
        return self.limite
    
    def sacar_dinheiro(self, valor):
        if self.saldo - valor < self.limite_conta():
            print('Você não tem saldo suficiente para sacar esse valor')
            self.consultar_saldo()
        else:
            self.saldo -= valor
    
    
#programa

conta_Lira = ContaCorrente("Lira", "111.222.333-45")
conta_Lira.consultar_saldo()

#depositando
conta_Lira.depositar(10000)
conta_Lira.consultar_saldo()

#sacando
conta_Lira.sacar_dinheiro(11000)
print('Saldo Final')
conta_Lira.consultar_saldo()
# Out:
# Seu saldo atual é de R$0.00
# Seu saldo atual é de R$10,000.00
# Saldo Final
# Seu saldo atual é de R$-1,000.00

# %%
class ContaCorrente:
    
    def __init__(self, nome, cpf):
        self.nome = nome
        self.cpf = cpf
        self.saldo = 0
        self.limite = None
       
    def consultar_saldo(self):
        print('Seu saldo atual é de R${:,.2f}'.format(self.saldo))
        
    def depositar(self, valor):
        self.saldo += valor
            
    def _limite_conta(self):      # método privado _
        self.limite = -1000
        return self.limite
    
    def sacar_dinheiro(self, valor):
        if self.saldo - valor < self._limite_conta():
            print('Você não tem saldo suficiente para sacar esse valor')
            self.consultar_saldo()
        else:
            self.saldo -= valor
            
    def consultar_limite_chequeespecial(self):
        print('Seu limite de cheque especial é de R${:,.2f}'.format(self._limite_conta()))
    
#programa

conta_Lira = ContaCorrente("Lira", "111.222.333-45")
conta_Lira.consultar_saldo()

#depositando
conta_Lira.depositar(10000)
conta_Lira.consultar_saldo()

#sacando
conta_Lira.sacar_dinheiro(11500)

print('Saldo Final')
conta_Lira.consultar_saldo()
conta_Lira.consultar_limite_chequeespecial()
# Out:
# Seu saldo atual é de R$0.00
# Seu saldo atual é de R$10,000.00
# Você não tem saldo suficiente para sacar esse valor
# Seu saldo atual é de R$10,000.00
# Saldo Final
# Seu saldo atual é de R$10,000.00
# Seu limite de cheque especial é de R$-1,000.00

# %%
class ContaCorrente:
    
    def __init__(self, nome, cpf, agencia, num_conta):
        self.nome = nome
        self.cpf = cpf
        self.saldo = 0
        self.limite = None
        self.agencia = agencia
        self.num_conta = num_conta
       
    def consultar_saldo(self):
        print('Seu saldo atual é de R${:,.2f}'.format(self.saldo))
        
    def depositar(self, valor):
        self.saldo += valor
            
    def _limite_conta(self):      # método privado _
        self.limite = -1000
        return self.limite
    
    def sacar_dinheiro(self, valor):
        if self.saldo - valor < self._limite_conta():
            print('Você não tem saldo suficiente para sacar esse valor')
            self.consultar_saldo()
        else:
            self.saldo -= valor
            
    def consultar_limite_chequeespecial(self):
        print('Seu limite de cheque especial é de R${:,.2f}'.format(self._limite_conta()))
    
#programa

conta_Lira = ContaCorrente("Lira", "111.222.333-45")
conta_Lira.consultar_saldo()

#depositando
conta_Lira.depositar(10000)
conta_Lira.consultar_saldo()

#sacando
conta_Lira.sacar_dinheiro(11500)

print('Saldo Final')
conta_Lira.consultar_saldo()
conta_Lira.consultar_limite_chequeespecial()   # a msg de erro foi pq não indiquei agencia e num
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-77ca9accda99> in <module>
#      31 #programa
#      32
# ---> 33 conta_Lira = ContaCorrente("Lira", "111.222.333-45")
#      34 conta_Lira.consultar_saldo()
#      35
#
# TypeError: __init__() missing 2 required positional arguments: 'agencia' and 'num_conta'

# %%
class ContaCorrente:
    
    def __init__(self, nome, cpf, agencia, num_conta):
        self.nome = nome
        self.cpf = cpf
        self.saldo = 0
        self.limite = None
        self.agencia = agencia
        self.num_conta = num_conta
       
    def consultar_saldo(self):
        print('Seu saldo atual é de R${:,.2f}'.format(self.saldo))
        
    def depositar(self, valor):
        self.saldo += valor
            
    def _limite_conta(self):      # método privado _ usado somente dentro da classe
        self.limite = -1000
        return self.limite
    
    def sacar_dinheiro(self, valor):
        if self.saldo - valor < self._limite_conta():
            print('Você não tem saldo suficiente para sacar esse valor')
            self.consultar_saldo()
        else:
            self.saldo -= valor
            
    def consultar_limite_chequeespecial(self):
        print('Seu limite de cheque especial é de R${:,.2f}'.format(self._limite_conta()))
  

#programa

conta_Lira = ContaCorrente("Lira", "111.222.333-45", 1234, 34062)
conta_Lira.consultar_saldo()

#depositando
conta_Lira.depositar(10000)
conta_Lira.consultar_saldo()

#sacando
conta_Lira.sacar_dinheiro(11500)

print('Saldo Final')
conta_Lira.consultar_saldo()
conta_Lira.consultar_limite_chequeespecial()
# Out:
# Seu saldo atual é de R$0.00
# Seu saldo atual é de R$10,000.00
# Você não tem saldo suficiente para sacar esse valor
# Seu saldo atual é de R$10,000.00
# Saldo Final
# Seu saldo atual é de R$10,000.00
# Seu limite de cheque especial é de R$-1,000.00

# %%
from datetime import datetime
import pytz # módulo que faz o ajuste de fuso horário ptyhon time-zone



class ContaCorrente:
    
    @staticmethod # método estático, não tem self, não usa nenhuma informação da classe.
    def _data_hora():
        fuso_BR = pytz.timezone('Brazil/East')  # fuso Brasília
        horario_BR = datetime.now(fuso_BR)  # é a time zone
        return horario_BR
        
    def __init__(self, nome, cpf, agencia, num_conta):
        self.nome = nome
        self.cpf = cpf
        self.saldo = 0
        self.limite = None
        self.agencia = agencia
        self.num_conta = num_conta
        self.transacoes = []
       
    def consultar_saldo(self):
        print('Seu saldo atual é de R${:,.2f}'.format(self.saldo))
        
    def depositar(self, valor):
        self.saldo += valor
        self.transacoes.append((valor, self.saldo, ContaCorrente._data_hora()))
        
    def _limite_conta(self):      # método privado _
        self.limite = -1000
        return self.limite
    
    def sacar_dinheiro(self, valor):
        if self.saldo - valor < self._limite_conta():
            print('Você não tem saldo suficiente para sacar esse valor')
            self.consultar_saldo()
        else:
            self.saldo -= valor
            self.transacoes.append((-valor, self.saldo, ContaCorrente._data_hora()))
            # append aceita um único argumento, por isso uma tupla
    def consultar_limite_chequeespecial(self):
        print('Seu limite de cheque especial é de R${:,.2f}'.format(self._limite_conta()))
    
    def consultar_historico_transacoes(self):
        print('Historico de Transações:')
        print('Valor, Saldo, Data e Hora')
        for transacao in self.transacoes:
            print(transacao)
    
#programa

conta_Lira = ContaCorrente("Lira", "111.222.333-45", 1234, 34062)
conta_Lira.consultar_saldo()

#depositando
conta_Lira.depositar(10000)
conta_Lira.consultar_saldo()

#sacando
conta_Lira.sacar_dinheiro(11500)

print('Saldo Final')
conta_Lira.consultar_saldo()
conta_Lira.consultar_limite_chequeespecial()

print('-' * 20)
conta_Lira.consultar_historico_transacoes()
# Out:
# Seu saldo atual é de R$0.00
# Seu saldo atual é de R$10,000.00
# Você não tem saldo suficiente para sacar esse valor
# Seu saldo atual é de R$10,000.00
# Saldo Final
# Seu saldo atual é de R$10,000.00
# Seu limite de cheque especial é de R$-1,000.00
# --------------------
# Historico de Transações:
# Valor, Saldo, Data e Hora
# (10000, 10000, datetime.datetime(2021, 11, 27, 15, 56, 2, 678308, tzinfo=<DstTzInfo 'Brazil/East' -03-1 day, 21:00:00 STD>))

# %%
from datetime import datetime
import pytz


class ContaCorrente:
    
    @staticmethod
    def _data_hora():
        fuso_BR = pytz.timezone('Brazil/East')
        horario_BR = datetime.now(fuso_BR)
        return horario_BR.strftime('%d/%m/%Y %H:%M:%S')
        
    def __init__(self, nome, cpf, agencia, num_conta):
        self.nome = nome
        self.cpf = cpf
        self.saldo = 0
        self.limite = None
        self.agencia = agencia
        self.num_conta = num_conta
        self.transacoes = []
       
    def consultar_saldo(self):
        print('Seu saldo atual é de R${:,.2f}'.format(self.saldo))
        
    def depositar(self, valor):
        self.saldo += valor
        self.transacoes.append((valor, self.saldo, ContaCorrente._data_hora()))
        
    def _limite_conta(self):      # método privado _
        self.limite = -1000
        return self.limite
    
    def sacar_dinheiro(self, valor):
        if self.saldo - valor < self._limite_conta():
            print('Você não tem saldo suficiente para sacar esse valor')
            self.consultar_saldo()
        else:
            self.saldo -= valor
            self.transacoes.append((-valor, self.saldo, ContaCorrente._data_hora()))
            
    def consultar_limite_chequeespecial(self):
        print('Seu limite de cheque especial é de R${:,.2f}'.format(self._limite_conta()))
    
    def consultar_historico_transacoes(self):
        print('Historico de Transações:')
        print('Valor, Saldo, Data e Hora')
        for transacao in self.transacoes:
            print(transacao)
    
#programa

conta_Lira = ContaCorrente("Lira", "111.222.333-45", 1234, 34062)
conta_Lira.consultar_saldo()

#depositando
conta_Lira.depositar(10000)
conta_Lira.consultar_saldo()

#sacando
conta_Lira.sacar_dinheiro(11500)

print('Saldo Final')
conta_Lira.consultar_saldo()
conta_Lira.consultar_limite_chequeespecial()

print('-' * 20)
conta_Lira.consultar_historico_transacoes()
# Out:
# Seu saldo atual é de R$0.00
# Seu saldo atual é de R$10,000.00
# Você não tem saldo suficiente para sacar esse valor
# Seu saldo atual é de R$10,000.00
# Saldo Final
# Seu saldo atual é de R$10,000.00
# Seu limite de cheque especial é de R$-1,000.00
# --------------------
# Historico de Transações:
# Valor, Saldo, Data e Hora
# (10000, 10000, '27/11/2021 15:56:02')

# %%
from datetime import datetime   #3318 - 34
import pytz


class ContaCorrente:
    
    @staticmethod
    def _data_hora():
        fuso_BR = pytz.timezone('Brazil/East')
        horario_BR = datetime.now(fuso_BR)
        return horario_BR.strftime('%d/%m/%Y %H:%M:%S')
        
    def __init__(self, nome, cpf, agencia, num_conta):
        self.nome = nome
        self.cpf = cpf
        self.saldo = 0
        self.limite = None
        self.agencia = agencia
        self.num_conta = num_conta
        self.transacoes = []
       
    def consultar_saldo(self):
        print('Seu saldo atual é de R${:,.2f}'.format(self.saldo))
        
    def depositar(self, valor):
        self.saldo += valor
        self.transacoes.append((valor, self.saldo, ContaCorrente._data_hora()))
        
    def _limite_conta(self):      # método privado _
        self.limite = -1000
        return self.limite
    
    def sacar_dinheiro(self, valor):
        if self.saldo - valor < self._limite_conta():
            print('Você não tem saldo suficiente para sacar esse valor')
            self.consultar_saldo()
        else:
            self.saldo -= valor
            self.transacoes.append((-valor, self.saldo, ContaCorrente._data_hora()))
            
    def consultar_limite_chequeespecial(self):
        print('Seu limite de cheque especial é de R${:,.2f}'.format(self._limite_conta()))
    
    def consultar_historico_transacoes(self):
        print('Historico de Transações:')
        print('Valor, Saldo, Data e Hora')
        for transacao in self.transacoes:
            print(transacao)
            
    def transferir(self, valor, conta_destino):
        self.saldo = self.saldo - valor
        self.transacoes.append((-valor, self.saldo, ContaCorrente._data_hora()))
        conta_destino.saldo = conta_destino.saldo + valor
        conta_destino.transacoes.append((valor, conta_destino.saldo, ContaCorrente._data_hora()))
        
        
        
#programa

conta_Lira = ContaCorrente("Lira", "111.222.333-45", 1234, 34062)
conta_Lira.consultar_saldo()

#depositando
conta_Lira.depositar(10000)
conta_Lira.consultar_saldo()

#sacando
conta_Lira.sacar_dinheiro(0)

print('Saldo Final')
conta_Lira.consultar_saldo()
conta_Lira.consultar_limite_chequeespecial()

print('-' * 20)
conta_Lira.consultar_historico_transacoes()

print('-' * 20)
conta_maeLira = ContaCorrente('Beth', '222.333.444-55', 5555, 656565) #cria conta maeLira
conta_Lira.transferir(1000, conta_maeLira)

conta_Lira.consultar_saldo()
conta_maeLira.consultar_saldo()

conta_Lira.consultar_historico_transacoes()
conta_maeLira.consultar_historico_transacoes()
# Out:
# Seu saldo atual é de R$0.00
# Seu saldo atual é de R$10,000.00
# Saldo Final
# Seu saldo atual é de R$10,000.00
# Seu limite de cheque especial é de R$-1,000.00
# --------------------
# Historico de Transações:
# Valor, Saldo, Data e Hora
# (10000, 10000, '27/11/2021 15:56:03')
# (0, 10000, '27/11/2021 15:56:03')
# --------------------
# Seu saldo atual é de R$9,000.00
# Seu saldo atual é de R$1,000.00
# Historico de Transações:
# Valor, Saldo, Data e Hora
# (10000, 10000, '27/11/2021 15:56:03')
# (0, 10000, '27/11/2021 15:56:03')
# (-1000, 9000, '27/11/2021 15:56:03')
# Historico de Transações:
# Valor, Saldo, Data e Hora
# (1000, 1000, '27/11/2021 15:56:03')

# %%
from datetime import datetime
import pytz
from random import randint


class ContaCorrente:  # 3321 - 34
    
    @staticmethod
    def _data_hora():
        fuso_BR = pytz.timezone('Brazil/East')
        horario_BR = datetime.now(fuso_BR)
        return horario_BR.strftime('%d/%m/%Y %H:%M:%S')
        
    def __init__(self, nome, cpf, agencia, num_conta):
        self._nome = nome
        self._cpf = cpf
        self._saldo = 0
        self._limite = None
        self._agencia = agencia
        self._num_conta = num_conta
        self._transacoes = []
        self.cartoes = []
        
    def consultar_saldo(self):
        print('Seu saldo atual é de R${:,.2f}'.format(self._saldo))
        
    def depositar(self, valor):
        self.saldo += valor
        self.transacoes.append((valor, self._saldo, ContaCorrente._data_hora()))
        
    def _limite_conta(self):      # método privado _
        self.limite = -1000
        return self.limite
    
    def sacar_dinheiro(self, valor):
        if self.saldo - valor < self._limite_conta():
            print('Você não tem saldo suficiente para sacar esse valor')
            self.consultar_saldo()
        else:
            self._saldo -= valor
            self._transacoes.append((-valor, self._saldo, ContaCorrente._data_hora()))
            
    def consultar_limite_chequeespecial(self):
        print('Seu limite de cheque especial é de R${:,.2f}'.format(self._limite_conta()))
    
    def consultar_historico_transacoes(self):
        print('Historico de Transações:')
        print('Valor, Saldo, Data e Hora')
        for transacao in self.transacoes:
            print(transacao)
            
    def transferir(self, valor, conta_destino):
        self._saldo = self._saldo - valor
        self._transacoes.append((-valor, self._saldo, ContaCorrente._data_hora()))
        conta_destino._saldo = conta_destino.saldo + valor
        conta_destino._transacoes.append((valor, conta_destino._saldo, ContaCorrente._data_hora()))
        
class CartaoCredito:
    
    @staticmethod
    def _data_hora():
        fuso_BR = pytz.timezone('Brazil/East')
        horario_BR = datetime.now(fuso_BR)
        return horario_BR
    
    def __init__(self, titular, conta_corrente):
        self.numero = randint(1000000000000000, 9999999999999999)
        self.titular = titular
        self.validade = '{}/{}'.format(CartaoCredito._data_hora().month, CartaoCredito._data_hora().year + 4)
        self.cod_seguranca = '{}{}{}'.format(randint(0, 9), randint(0, 9), randint(0, 9))
        self.limite = 1000
        self.conta_corrente = conta_corrente
        conta_corrente.cartoes.append(self)
        
        
#programa

conta_Lira = ContaCorrente("Lira", "111.222.333-45", 1234, 34062)

cartao_Lira = CartaoCredito('Lira', conta_Lira)

print(cartao_Lira.conta_corrente._num_conta)

print(cartao_Lira.numero)

print(cartao_Lira.validade)

print(cartao_Lira.cod_seguranca)
# Out:
# 34062
# 9616375032770785
# 11/2025
# 073

# %%
from datetime import datetime
import pytz
from random import randint


class ContaCorrente:  # 3321 - 34
    
    @staticmethod
    def _data_hora():
        fuso_BR = pytz.timezone('Brazil/East')
        horario_BR = datetime.now(fuso_BR)
        return horario_BR.strftime('%d/%m/%Y %H:%M:%S')
        
    def __init__(self, nome, cpf, agencia, num_conta):
        self.nome = nome
        self.cpf = cpf
        self._saldo = 0
        self._limite = None
        self._agencia = agencia
        self._num_conta = num_conta
        self._transacoes = []
        self.cartoes = []
        
    def consultar_saldo(self):
        print('Seu saldo atual é de R${:,.2f}'.format(self._saldo))
        
    def depositar(self, valor):
        self.saldo += valor
        self.transacoes.append((valor, self._saldo, ContaCorrente._data_hora()))
        
    def _limite_conta(self):      # método privado _
        self.limite = -1000
        return self.limite
    
    def sacar_dinheiro(self, valor):
        if self.saldo - valor < self._limite_conta():
            print('Você não tem saldo suficiente para sacar esse valor')
            self.consultar_saldo()
        else:
            self._saldo -= valor
            self._transacoes.append((-valor, self._saldo, ContaCorrente._data_hora()))
            
    def consultar_limite_chequeespecial(self):
        print('Seu limite de cheque especial é de R${:,.2f}'.format(self._limite_conta()))
    
    def consultar_historico_transacoes(self):
        print('Historico de Transações:')
        print('Valor, Saldo, Data e Hora')
        for transacao in self.transacoes:
            print(transacao)
            
    def transferir(self, valor, conta_destino):
        self._saldo = self._saldo - valor
        self._transacoes.append((-valor, self._saldo, ContaCorrente._data_hora()))
        conta_destino._saldo = conta_destino.saldo + valor
        conta_destino._transacoes.append((valor, conta_destino._saldo, ContaCorrente._data_hora()))
        
class CartaoCredito:
    
    @staticmethod
    def _data_hora():
        fuso_BR = pytz.timezone('Brazil/East')
        horario_BR = datetime.now(fuso_BR)
        return horario_BR
    
    def __init__(self, titular, conta_corrente):
        self.numero = randint(1000000000000000, 9999999999999999)
        self.titular = titular
        self.validade = '{}/{}'.format(CartaoCredito._data_hora().month, CartaoCredito._data_hora().year + 4)
        self.cod_seguranca = '{}{}{}'.format(randint(0, 9), randint(0, 9), randint(0, 9))
        self.limite = 1000
        self._senha = '1234'
        self.conta_corrente = conta_corrente
        conta_corrente.cartoes.append(self)
        
    @property
    def senha(self):
        return self._senha
    
    @senha.setter
    def senha(self, valor):
        if len(valor) == 4 and valor.isnumeric():
            self._senha = valor
        else:
            print('Nova Senha Inválida')
        
        


conta_Lira = ContaCorrente("Lira", "111.222.333-45", 1234, 34062)

cartao_Lira = CartaoCredito('Lira', conta_Lira)

cartao_Lira.nome = "João Lira"
print(conta_Lira.nome)

cartao_Lira.senha = '12'
print(cartao_Lira.senha)

print(conta_Lira.__dict__)
# Out:
# Lira
# Nova Senha Inválida
# 1234
# {'nome': 'Lira', 'cpf': '111.222.333-45', '_saldo': 0, '_limite': None, '_agencia': 1234, '_num_conta': 34062, '_transacoes': [], 'cartoes': [<__main__.CartaoCredito object at 0x00000172CB230430>]}
