# %%
import pandas as pd

vendas_df = pd.read_csv('Contoso - Cadastro Produtos.csv')

print(vendas_df) # bem estranho, não?
# Out:
#                                                                 Nome da Marca;Tipo;Custo Unitario;Preco Unitario;ID Produto;Categoria
# Contoso;Econômico;10        69;20                                                 96;873;Acessório para Computador
# Contoso;Econômico;6         63;13;879;Acessório para Computador                                                NaN
#                             63;13;880;Acessório para Computador                                                NaN
#                             63;13;881;Acessório para Computador                                                NaN
#                             63;13;882;Acessório para Computador                                                NaN
# ...                                                                                                            ...
# Southridge Video;Regular;82 77;179                                                               99;1602;Filme DVD
# ...

# %%
import pandas as pd

vendas_df = pd.read_csv('Contoso - Cadastro Produtos.csv')

vendas_df  # um pouco mais organizada
# Out:
#                                                                 Nome da Marca;Tipo;Custo Unitario;Preco Unitario;ID Produto;Categoria
# Contoso;Econômico;10        69;20                                                 96;873;Acessório para Computador
# Contoso;Econômico;6         63;13;879;Acessório para Computador                                                NaN
#                             63;13;880;Acessório para Computador                                                NaN
#                             63;13;881;Acessório para Computador                                                NaN
#                             63;13;882;Acessório para Computador                                                NaN
# ...                                                                                                            ...
# Southridge Video;Regular;82 77;179                                                               99;1602;Filme DVD
# ...

# %%
vendas_df = pd.read_csv('Contoso - Vendas - 2017.csv')

vendas_df
# Out:
#        Numero da Venda;Data da Venda;Data do Envio;ID Canal;ID Loja;ID Produto;ID Promocao;ID Cliente;Quantidade Vendida;Quantidade Devolvida
# 0             1;01/01/2017;02/01/2017;1;86;981;2;6825;9;1
# 1          2;01/01/2017;06/01/2017;5;308;1586;2;18469;9;1
# 2         3;01/01/2017;01/01/2017;0;294;1444;5;19730;13;1
# 3          4;01/01/2017;01/01/2017;0;251;1468;5;29326;6;1
# 4           5;01/01/2017;07/01/2017;6;94;1106;2;22617;4;1
# ...                                                   ...
# 980637  980638;31/12/2017;31/12/2017;0;194;2490;4;1035...
# 980638  980639;31/12/2017;06/01/2018;6;32;2488;4;31750...
# 980639  980640;31/12/2017;03/01/2018;3;210;2511;10;120...
# 980640  980641;31/12/2017;31/12/2017;0;53;436;4;25550;...
# 980641  980642;31/12/2017;31/12/2017;0;309;2510;10;287...
#
# [980642 rows x 1 columns]

# %%
vendas_df = pd.read_csv('Contoso - Vendas - 2017.csv', sep=';')

vendas_df  # trocando o csv para o de Vendas, com o parâmetro separador ';'
''' trocando o csv para o de Vendas, sem o parâmetro separador, fica uma única coluna. 
Essa tabela criada no pandas é um dataframe'''
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 0                     1    01/01/2017    02/01/2017         1       86
# 1                     2    01/01/2017    06/01/2017         5      308
# 2                     3    01/01/2017    01/01/2017         0      294
# 3                     4    01/01/2017    01/01/2017         0      251
# 4                     5    01/01/2017    07/01/2017         6       94
# ...                 ...           ...           ...       ...      ...
# 980637           980638    31/12/2017    31/12/2017         0      194
# 980638           980639    31/12/2017    06/01/2018         6       32
# 980639           980640    31/12/2017    03/01/2018         3      210
# 980640           980641    31/12/2017    31/12/2017         0       53
# 980641           980642    31/12/2017    31/12/2017         0      309
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# ...

# %%
vendas_df = pd.read_csv(r'H:\Hashtag\19 Análise de Dados com o Pandas + Integração Python e Excel\Contoso - Vendas - 2017.csv', sep=';')

vendas_df  ''' sem colocar o arquivo csv no diretório C, então é preciso mostrar o caminho
de onde está o arquivo, acrescentar ao final o nome do arquivo e no início o 'r'. Esse r diz
ao python que é uma raw string então ele não vai ficar tentando ler, identificar esse texto ou
procurando algum comando do python'''
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 0                     1    01/01/2017    02/01/2017         1       86
# 1                     2    01/01/2017    06/01/2017         5      308
# 2                     3    01/01/2017    01/01/2017         0      294
# 3                     4    01/01/2017    01/01/2017         0      251
# 4                     5    01/01/2017    07/01/2017         6       94
# ...                 ...           ...           ...       ...      ...
# 980637           980638    31/12/2017    31/12/2017         0      194
# 980638           980639    31/12/2017    06/01/2018         6       32
# 980639           980640    31/12/2017    03/01/2018         3      210
# 980640           980641    31/12/2017    31/12/2017         0       53
# 980641           980642    31/12/2017    31/12/2017         0      309
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# ...

# %%
'''Temos um dataframe chamado vendas_df

vendas_df['coluna_x'] -> uma lista com os valores da coluna_x (em formato dataframe, é um dataframe com 1 coluna só)
vendas_df[0] -> NÃO FUNCIONA ASSIM PARA DATAFRAMES
vendas_df[:3] -> pega até a linha de índice 3 do dataframe
vendas_df[['coluna_x', 'coluna_y', 'coluna_z']] -> cria um novo dataframe com as colunas coluna_x, coluna_y e coluna_z
vendas_df['coluna_x'][0] -> pega o itemd a 1ª linha da coluna coluna_x'''

# %%
vendas_df['ID Loja']
# Out:
# 0          86
# 1         308
# 2         294
# 3         251
# 4          94
#          ...
# 980637    194
# 980638     32
# 980639    210
# 980640     53
# 980641    309
# Name: ID Loja, Length: 980642, dtype: int64

# %%
vendas_df[:3]  # pega até a linha de índice 3
# Out:
#    Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  ID Produto  \
# 0                1    01/01/2017    02/01/2017         1       86         981
# 1                2    01/01/2017    06/01/2017         5      308        1586
# 2                3    01/01/2017    01/01/2017         0      294        1444
#
#    ID Promocao  ID Cliente  Quantidade Vendida  Quantidade Devolvida
# 0            2        6825                   9                     1
# 1            2       18469                   9                     1
# 2            5       19730                  13                     1

# %%
vendas_df[['Data da Venda', 'ID Canal', 'ID Cliente']] # cria um novo dataframe com as colunas especificadas
# Out:
#        Data da Venda  ID Canal  ID Cliente
# 0         01/01/2017         1        6825
# 1         01/01/2017         5       18469
# 2         01/01/2017         0       19730
# 3         01/01/2017         0       29326
# 4         01/01/2017         6       22617
# ...              ...       ...         ...
# 980637    31/12/2017         0       10353
# 980638    31/12/2017         6       31750
# 980639    31/12/2017         3       12003
# 980640    31/12/2017         0       25550
# 980641    31/12/2017         0       28707
#
# [980642 rows x 3 columns]

# %%
vendas_df['ID Produto'][0]
# Out:
# 981

# %%
# O 1o passo na análise de dados é você entender o que existe na sua base de dados.
# para isso vamos usar o .info()

vendas_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 980642 entries, 0 to 980641
# Data columns (total 10 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Numero da Venda       980642 non-null  int64
#  1   Data da Venda         980642 non-null  object
#  2   Data do Envio         980642 non-null  object
#  3   ID Canal              980642 non-null  int64
#  4   ID Loja               980642 non-null  int64
#  5   ID Produto            980642 non-null  int64
#  6   ID Promocao           980642 non-null  int64
#  7   ID Cliente            980642 non-null  int64
#  8   Quantidade Vendida    980642 non-null  int64
#  9   Quantidade Devolvida  980642 non-null  int64
# dtypes: int64(8), object(2)
# memory usage: 74.8+ MB

# %%
vendas_df['ID Loja']
# Out:
# 0          86
# 1         308
# 2         294
# 3         251
# 4          94
#          ...
# 980637    194
# 980638     32
# 980639    210
# 980640     53
# 980641    309
# Name: ID Loja, Length: 980642, dtype: int64

# %%
vendas_df['ID Cliente']
# Out:
# 0          6825
# 1         18469
# 2         19730
# 3         29326
# 4         22617
#           ...
# 980637    10353
# 980638    31750
# 980639    12003
# 980640    25550
# 980641    28707
# Name: ID Cliente, Length: 980642, dtype: int64

# %%
lista_clientes = vendas_df['ID Cliente']
lista_clientes
# Out:
# 0          6825
# 1         18469
# 2         19730
# 3         29326
# 4         22617
#           ...
# 980637    10353
# 980638    31750
# 980639    12003
# 980640    25550
# 980641    28707
# Name: ID Cliente, Length: 980642, dtype: int64

# %%
lista_colunas = ['ID Produto', 'Quantidade Vendida', 'Quantidade Devolvida']
produtos_quantidade = vendas_df[lista_colunas]
produtos_quantidade
# Out:
#         ID Produto  Quantidade Vendida  Quantidade Devolvida
# 0              981                   9                     1
# 1             1586                   9                     1
# 2             1444                  13                     1
# 3             1468                   6                     1
# 4             1106                   4                     1
# ...            ...                 ...                   ...
# 980637        2490                 120                     0
# 980638        2488                 120                     0
# 980639        2511                  80                     0
# 980640         436                  39                     0
# 980641        2510                  80                     0
#
# [980642 rows x 3 columns]

# %% [markdown]
# ## Comporando, Tratando e Mesclando DataFrames

# %%
# vamos modificar os ID´s para os nomes dos produtos, dos clientes e das lojas, para nossas análises ficarem mais 
# intuitivas futuramente. Vamos criar um dataframe com todos os detalhes.

# %% [markdown]
# ## Criando nossos dataframes

# %%
import pandas as pd

#às vezes precisaremos mudar o encoding. Possiveis valores para testar:
#encoding='latin1', encoding='ISO-8859-1', encoding='utf-8' ou então encoding='cp1252'

vendas_df = pd.read_csv('Contoso - Vendas - 2017.csv', sep=';')
produtos_df = pd.read_csv('Contoso - Cadastro Produtos.csv', sep=';')
lojas_df = pd.read_csv('Contoso - Lojas.csv', sep=';')
clientes_df = pd.read_csv('Contoso - Clientes.csv', sep=';')

#usaremos o display para ver todos os dataframes
display(vendas_df)
display(produtos_df)
display(lojas_df)
display(clientes_df)
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 0                     1    01/01/2017    02/01/2017         1       86
# 1                     2    01/01/2017    06/01/2017         5      308
# 2                     3    01/01/2017    01/01/2017         0      294
# 3                     4    01/01/2017    01/01/2017         0      251
# 4                     5    01/01/2017    07/01/2017         6       94
# ...                 ...           ...           ...       ...      ...
# 980637           980638    31/12/2017    31/12/2017         0      194
# 980638           980639    31/12/2017    06/01/2018         6       32
# 980639           980640    31/12/2017    03/01/2018         3      210
# 980640           980641    31/12/2017    31/12/2017         0       53
# 980641           980642    31/12/2017    31/12/2017         0      309
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# ...

# %% [markdown]
# ## vamos tirar as colunas inúteis do clientes_df ou pegar as colunas que quisermos
#
# .drop([coluna1, coluna2, coluna3]) -> retira as colunas: coluna1, coluna2, coluna3

# %%
clientes_df = clientes_df.drop(['Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10'], axis=1)
display(clientes_df)  # usamos o drop para retirar porém é preciso indicar o eixo 1 para colunas
# Out:
#        ID Cliente Primeiro Nome     Sobrenome                         E-mail  \
# 0               1        Garnet    Lanfranchi    glanfranchi0@mayoclinic.com
# 1               2       Lurette     Roseblade      lroseblade1@bigcartel.com
# 2               3       Glenden     Ishchenko      gishchenko2@moonfruit.com
# 3               4         Baron  Jedrzejewsky    bjedrzejewsky3@e-recht24.de
# 4               5        Sheree      Bredbury       sbredbury4@sitemeter.com
# ...           ...           ...           ...                            ...
# 39499       39500        Brandy      Malhotra    brandy0@adventure-works.com
# 39500       39501        Alicia          Raje   alicia12@adventure-works.com
# 39501       39502        Connie           Rai    connie4@adventure-works.com
# 39502       39503         Shawn          Raji    shawn23@adventure-works.com
# 39503       39504       Lindsey        Sharma  lindsey10@adventure-works.com
#
# ...

# %%
clientes_df = clientes_df[['ID Cliente', 'E-mail']]
produtos_df = produtos_df[['ID Produto', 'Nome do Produto']]
lojas_df = lojas_df[['ID Loja', 'Nome da Loja']]
display(clientes_df)
display(produtos_df)
display(lojas_df)
# Out:
#        ID Cliente                         E-mail
# 0               1    glanfranchi0@mayoclinic.com
# 1               2      lroseblade1@bigcartel.com
# 2               3      gishchenko2@moonfruit.com
# 3               4    bjedrzejewsky3@e-recht24.de
# 4               5       sbredbury4@sitemeter.com
# ...           ...                            ...
# 39499       39500    brandy0@adventure-works.com
# 39500       39501   alicia12@adventure-works.com
# 39501       39502    connie4@adventure-works.com
# 39502       39503    shawn23@adventure-works.com
# 39503       39504  lindsey10@adventure-works.com
#
# [39504 rows x 2 columns]
#       ID Produto                                  Nome do Produto
# 0            873            Contoso Wireless Laser Mouse E50 Grey
# 1            879    Contoso Optical Wheel OEM PS/2 Mouse E60 Grey
# 2            880   Contoso Optical Wheel OEM PS/2 Mouse E60 Black
# 3            881   Contoso Optical Wheel OEM PS/2 Mouse E60 White
# ...

# %%
#juntando os dataframes
vendas_df = vendas_df.merge(produtos_df, on='ID Produto')
vendas_df = vendas_df.merge(lojas_df, on='ID Loja')
vendas_df = vendas_df.merge(clientes_df, on='ID Cliente')

#exibindo o dataframe final
display(vendas_df)
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 0                     1    01/01/2017    02/01/2017         1       86
# 1                880458    23/11/2017    23/11/2017         0      306
# 2                191019    20/03/2017    21/03/2017         1      172
# 3                 18610    08/01/2017    10/01/2017         2      200
# 4                287704    23/04/2017    26/04/2017         3       76
# ...                 ...           ...           ...       ...      ...
# 980637           878244    23/11/2017    23/11/2017         0      110
# 980638           920243    09/12/2017    10/12/2017         1      261
# 980639           467482    21/06/2017    25/06/2017         4      115
# 980640           853643    13/11/2017    20/11/2017         7      115
# 980641           903958    02/12/2017    02/12/2017         0      222
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# ...

# %%
#vamos renomear o email para ficar claro que é o email do cliente

vendas_df = vendas_df.rename(columns={'E-mail': 'E-mail do Cliente'})
display(vendas_df)
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 0                     1    01/01/2017    02/01/2017         1       86
# 1                880458    23/11/2017    23/11/2017         0      306
# 2                191019    20/03/2017    21/03/2017         1      172
# 3                 18610    08/01/2017    10/01/2017         2      200
# 4                287704    23/04/2017    26/04/2017         3       76
# ...                 ...           ...           ...       ...      ...
# 980637           878244    23/11/2017    23/11/2017         0      110
# 980638           920243    09/12/2017    10/12/2017         1      261
# 980639           467482    21/06/2017    25/06/2017         4      115
# 980640           853643    13/11/2017    20/11/2017         7      115
# 980641           903958    02/12/2017    02/12/2017         0      222
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# ...

# %% [markdown]
# # Resumo das Aulas Anteriores e Plotagem de Gráficos

# %%
import pandas as pd

#às vezes precisaremos mudar o encoding. Possiveis valores para testar:
#encoding='latin1', encoding='ISO-8859-1', encoding='utf-8' ou então encoding='cp1252'

vendas_df = pd.read_csv('Contoso - Vendas - 2017.csv', sep=';')
produtos_df = pd.read_csv('Contoso - Cadastro Produtos.csv', sep=';')
lojas_df = pd.read_csv('Contoso - Lojas.csv', sep=';')
clientes_df = pd.read_csv('Contoso - Clientes.csv', sep=';')

#limpando as colunas que queremos

clientes_df = clientes_df[['ID Cliente', 'E-mail']]
produtos_df = produtos_df[['ID Produto', 'Nome do Produto']]
lojas_df = lojas_df[['ID Loja', 'Nome da Loja']]

#mesclando e renomeando os dataframes

vendas_df = vendas_df.merge(produtos_df, on='ID Produto')
vendas_df = vendas_df.merge(lojas_df, on='ID Loja')
vendas_df = vendas_df.merge(clientes_df, on='ID Cliente')

#alterando nome da colua E-mail apra E-mail Cliente
vendas_df = vendas_df.rename(columns={'E-mail': 'E-mail do Cliente'})
display(vendas_df)

#exibindo o dataframe final
display(vendas_df)
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 0                     1    01/01/2017    02/01/2017         1       86
# 1                880458    23/11/2017    23/11/2017         0      306
# 2                191019    20/03/2017    21/03/2017         1      172
# 3                 18610    08/01/2017    10/01/2017         2      200
# 4                287704    23/04/2017    26/04/2017         3       76
# ...                 ...           ...           ...       ...      ...
# 980637           878244    23/11/2017    23/11/2017         0      110
# 980638           920243    09/12/2017    10/12/2017         1      261
# 980639           467482    21/06/2017    25/06/2017         4      115
# 980640           853643    13/11/2017    20/11/2017         7      115
# 980641           903958    02/12/2017    02/12/2017         0      222
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# ...

# %%
# qual o cliente que comprou mais vezes? Usaremos o e-mail para identificá-lo.
# usaremos o método .value_counts() para contar contas vezes cada valor do DataFrame aparece (escolhi ver o email)
# usaremos o método .plot() para exibir um gráfico

frequencia_clientes = vendas_df['E-mail do Cliente'].value_counts()
frequencia_clientes
# Out:
# karen33@adventure-works.com       77
# chloe77@adventure-works.com       74
# julia43@adventure-works.com       69
# destiny66@adventure-works.com     68
# gilbert9@adventure-works.com      68
#                                   ..
# isabella51@adventure-works.com     1
# wdalescoci@pbs.org                 1
# kbroggelliin@rakuten.co.jp         1
# connor15@adventure-works.com       1
# ekorneevmm@instagram.com           1
# Name: E-mail do Cliente, Length: 38907, dtype: int64

# %%
# qual o cliente que comprou mais vezes? Usaremos o e-mail para identificá-lo.
# usaremos o método .value_counts() para contar contas vezes cada valor do DataFrame aparece (escolhi ver o email)
# usaremos o método .plot() para exibir um gráfico

frequencia_clientes = vendas_df['E-mail do Cliente'].value_counts()
frequencia_clientes
frequencia_clientes.plot() #plota o gráfico com os mais de 38 mil clientes (38907)
# Out:
# <AxesSubplot:>

# %%
frequencia_clientes = vendas_df['E-mail do Cliente'].value_counts()
frequencia_clientes
frequencia_clientes[:5].plot() #plota o gráfico com os 5 principais clientes (38907)
# Out:
# <AxesSubplot:>

# %%
frequencia_clientes = vendas_df['E-mail do Cliente'].value_counts()
frequencia_clientes
frequencia_clientes[:5].plot(); #plota o gráfico com os 5 principais clientes (38907) o ;depois do plot serve para retirar
#o cabeçalho <AxesSubplot:>

# %%
frequencia_clientes = vendas_df['E-mail do Cliente'].value_counts()
frequencia_clientes
frequencia_clientes[:5].plot(figsize=(15, 5)); #figsize para esticar o gráfico (conseguimos ler os emails)

# %%
# Qual loja mais vendeu? Qtde

# %%
vendas_lojas = vendas_df.groupby('Nome da Loja').sum() 
display(vendas_lojas)
# Out:
#                           Numero da Venda  ID Canal  ID Loja  ID Produto  \
# Nome da Loja
# Loja Contoso Albany            1202431493      5537   279756     2256167
# Loja Contoso Alexandria        1180450098      5336   449696     2254764
# Loja Contoso Amsterdam         1463641203      6295   721440     2855945
# Loja Contoso Anchorage         1214566953      5441   458964     2328863
# Loja Contoso Annapolis         1196644689      5401   466995     2243342
# ...                                   ...       ...      ...         ...
# Loja Contoso Yokohama          1277269788      5423   681377     2331010
# Loja Contoso York              1447746885      6402   600372     2736443
# Loja Contoso koln No.1         1473231489      6712   699944     2802822
# Loja Contoso koln No.2         1495673435      6758   699430     2846553
# Loja Contoso obamberg          1443837839      6544   709240     2756377
#
#                           ID Promocao  ID Cliente  Quantidade Vendida  \
# ...

# %%
vendas_lojas = vendas_df.groupby('Nome da Loja').sum()  #agrupa as lojas e soma as qtdes
vendas_lojas = vendas_lojas[['Quantidade Vendida']]
display(vendas_lojas)
# Out:
#                           Quantidade Vendida
# Nome da Loja
# Loja Contoso Albany                    26353
# Loja Contoso Alexandria                26247
# Loja Contoso Amsterdam                 28294
# Loja Contoso Anchorage                 27451
# Loja Contoso Annapolis                 26065
# ...                                      ...
# Loja Contoso Yokohama                  28023
# Loja Contoso York                      27164
# Loja Contoso koln No.1                 29046
# Loja Contoso koln No.2                 29650
# Loja Contoso obamberg                  29336
#
# [306 rows x 1 columns]

# %%
vendas_lojas = vendas_df.groupby('Nome da Loja').sum()  #agrupa as lojas e soma as qtdes
vendas_lojas = vendas_lojas['Quantidade Vendida']
display(vendas_lojas)
# Out:
# Nome da Loja
# Loja Contoso Albany         26353
# Loja Contoso Alexandria     26247
# Loja Contoso Amsterdam      28294
# Loja Contoso Anchorage      27451
# Loja Contoso Annapolis      26065
#                             ...
# Loja Contoso Yokohama       28023
# Loja Contoso York           27164
# Loja Contoso koln No.1      29046
# Loja Contoso koln No.2      29650
# Loja Contoso obamberg       29336
# Name: Quantidade Vendida, Length: 306, dtype: int64

# %%
vendas_lojas = vendas_lojas.sort_values('Quantidade Vendida', ascending = False)
display(vendas_lojas)
# Out:
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_13268/3203769866.py:1: FutureWarning: In a future version of pandas all arguments of Series.sort_values will be keyword-only
#   vendas_lojas = vendas_lojas.sort_values('Quantidade Vendida', ascending = False)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\alexandre\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     545         try:
# --> 546             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     547         except KeyError:
#
# KeyError: 'Quantidade Vendida'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_13268/3203769866.py in <module>
# ...

# %% [markdown]
# # refazer aula 14min 59s
